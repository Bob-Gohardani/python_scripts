# %%
import pandas as pd
import numpy as np

# %%
na_vals = ['NA', 'Missing ']
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent', na_values=na_vals)
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
df.shape # shape of the dataframe
# Out:
# (88883, 84)

# %%
df.info()  # lists all columns and their data type, object usually means string in Pandas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88883 entries, 1 to 88863
# Data columns (total 84 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              88331 non-null  object
#  1   Hobbyist                88883 non-null  object
#  2   OpenSourcer             88883 non-null  object
#  3   OpenSource              86842 non-null  object
#  4   Employment              87181 non-null  object
#  5   Country                 88751 non-null  object
#  6   Student                 87014 non-null  object
#  7   EdLevel                 86390 non-null  object
#  8   UndergradMajor          75614 non-null  object
#  9   EduOther                84260 non-null  object
#  10  OrgSize                 71791 non-null  object
#  11  DevType                 81335 non-null  object
#  12  YearsCode               87938 non-null  object
#  13  Age1stCode              87634 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
# how a pandas dataframe works
# you can consider each key as a column name and each of ith items of lists as a row

people = {
    "first": ["Corey", "Jane", "John"],
    "last": ["Schafer", "Doe", "Deer"],
    "email": ["corey@gmail.com","jane@gmail.com", "JohnDoe@gmail.com"]
}

# %%
people_df = pd.DataFrame(people)
people_df
# Out:
#    first     last              email
# 0  Corey  Schafer    corey@gmail.com
# 1   Jane      Doe     jane@gmail.com
# 2   John     Deer  JohnDoe@gmail.com

# %%
type(people_df['email'])  # series can be looked as rows of a column, like a list in python
# Out:
# pandas.core.series.Series

# %%
people_df.email  # same as df['email']
# Out:
# 0      corey@gmail.com
# 1       jane@gmail.com
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %%
people_df[['last', 'email']]
# Out:
#       last              email
# 0  Schafer    corey@gmail.com
# 1      Doe     jane@gmail.com
# 2     Deer  JohnDoe@gmail.com

# %%
people_df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
people_df.iloc[0] # integer lookup, first column
# Out:
# first              Corey
# last             Schafer
# email    corey@gmail.com
# Name: 0, dtype: object

# %%
people_df.iloc[[0, 1], 2]
# Out:
# 0    corey@gmail.com
# 1     jane@gmail.com
# Name: email, dtype: object

# %%
people_df.loc[0]  # first row
# Out:
# first              Corey
# last             Schafer
# email    corey@gmail.com
# Name: 0, dtype: object

# %%
people_df.loc[[0, 1], ['email', 'last']]
# Out:
#              email     last
# 0  corey@gmail.com  Schafer
# 1   jane@gmail.com      Doe

# %%
df['DatabaseDesireNextYear'].value_counts()
# Out:
# PostgreSQL                                                                          3539
# Microsoft SQL Server                                                                3290
# MySQL                                                                               3184
# MongoDB                                                                             2250
# SQLite                                                                              1506
#                                                                                     ...
# Elasticsearch;Firebase;Microsoft SQL Server;MySQL;Oracle;PostgreSQL;Redis;SQLite       1
# Microsoft SQL Server;PostgreSQL;Redis;SQLite;Other(s):                                 1
# Couchbase;MariaDB;MongoDB;MySQL;PostgreSQL;Redis                                       1
# Cassandra;Elasticsearch;Firebase;Microsoft SQL Server;MySQL;Oracle;Redis;SQLite        1
# MongoDB;Microsoft SQL Server;MySQL;PostgreSQL;SQLite;Other(s):                         1
# ...

# %%
df.loc[[1, 2, 3], ['Hobbyist', 'DatabaseDesireNextYear']]
# Out:
#            Hobbyist DatabaseDesireNextYear
# Respondent
# 1               Yes                  MySQL
# 2                No                  MySQL
# 3               Yes             PostgreSQL

# %%
df.loc[1:4, ['Hobbyist', 'DatabaseDesireNextYear']]  # slicing in pandas is inclusive
# Out:
#            Hobbyist DatabaseDesireNextYear
# Respondent
# 1               Yes                  MySQL
# 2                No                  MySQL
# 3               Yes             PostgreSQL
# 4                No           MySQL;SQLite

# %%
df.loc[1:2, 'Hobbyist':'Employment']
# Out:
#            Hobbyist              OpenSourcer  \
# Respondent
# 1               Yes                    Never
# 2                No  Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment
# Respondent
# 1           Not employed, and not looking for work
# 2               Not employed, but looking for work

# %%
people_df.set_index('email')  # set a column as index of dataframe
# Out:
#                    first     last
# email
# corey@gmail.com    Corey  Schafer
# jane@gmail.com      Jane      Doe
# JohnDoe@gmail.com   John     Deer

# %%
people_df.set_index('email', inplace=True)  # applies changes to the current dataframe

# %%
people_df.reset_index(inplace=True)
people_df
# Out:
#                email  first     last
# 0    corey@gmail.com  Corey  Schafer
# 1     jane@gmail.com   Jane      Doe
# 2  JohnDoe@gmail.com   John     Deer

# %%
# schema_df.loc[['MgrIdiot', 'WorkChallenge']]
schema_df.columns
# Out:
# Index(['Column', 'QuestionText'], dtype='object')

# %%
schema_df.sort_index(ascending=False) # sort alphabetically from Z to A, default is True
# Out:
#                     Column                                       QuestionText
# 84              SurveyEase  How easy or difficult was this survey to compl...
# 83            SurveyLength  How do you feel about the length of the survey...
# 82              Dependents  Do you have any dependents (e.g., children, el...
# 81               Ethnicity  Which of the following do you identify as? Ple...
# 80               Sexuality  Which of the following do you currently identi...
# 79                   Trans                    Do you identify as transgender?
# 78                  Gender  Which of the following do you currently identi...
# 77                     Age  What is your age (in years)? If you prefer not...
# 76            SONewContent  Would you like to see any of the following on ...
# 75           WelcomeChange  Compared to last year, how welcome do you feel...
# 74                  SOComm  Do you consider yourself a member of the Stack...
# ...

# %%
filt = (people_df['last'] == 'Doe')  # returns a series with True/False
filt
# Out:
# 0    False
# 1     True
# 2    False
# Name: last, dtype: bool

# %%
people_df[filt]   # can also be people_df[people_df['last'] == 'Doe']
# Out:
#             email first last
# 1  jane@gmail.com  Jane  Doe

# %%
people_df.loc[filt, 'email']   # .loc[rows, columns]
# Out:
# 1    jane@gmail.com
# Name: email, dtype: object

# %%
# & : and   | : or
people_df.loc[(people_df['last'] == 'Doe') & (people_df['first'] == 'Jane') ]
# Out:
#             email first last
# 1  jane@gmail.com  Jane  Doe

# %%
people_df.loc[~filt, 'email'] # ~ is same as !=
# Out:
# 0      corey@gmail.com
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %%
high_salary = (df['ConvertedComp'] > 70000)

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']
filt = df['Country'].isin(countries)

df.loc[filt, 'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 6                Canada
# 8                 India
# 10                India
#               ...
# 85642     United States
# 85961    United Kingdom
# 86012             India
# 88282     United States
# 88377            Canada
# Name: Country, Length: 45008, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Swift', na=False)
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 21       Assembly;Bash/Shell/PowerShell;C;C++;Go;Java;J...
# 26       Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 90       Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 115         Assembly;C#;HTML/CSS;Java;JavaScript;SQL;Swift
# 152      HTML/CSS;Java;JavaScript;Kotlin;Objective-C;Py...
#                                ...
# 72325                     HTML/CSS;JavaScript;Python;Swift
# 75974    Go;HTML/CSS;Java;JavaScript;Kotlin;Python;Swif...
# 78741    Assembly;Bash/Shell/PowerShell;C;C++;C#;Clojur...
# 84299     HTML/CSS;Java;JavaScript;Python;Swift;TypeScript
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 5744, dtype: object

# %%
people_df.columns
# Out:
# Index(['email', 'first', 'last'], dtype='object')

# %%
people_df.columns = ['email', 'first_name', 'last_name']
people_df
# Out:
#                email first_name last_name
# 0    corey@gmail.com      Corey   Schafer
# 1     jane@gmail.com       Jane       Doe
# 2  JohnDoe@gmail.com       John      Deer

# %%
people_df.columns = [x.lower() for x in people_df.columns]
people_df
# Out:
#                email first_name last_name
# 0    corey@gmail.com      Corey   Schafer
# 1     jane@gmail.com       Jane       Doe
# 2  JohnDoe@gmail.com       John      Deer

# %%
people_df.columns = people_df.columns.str.replace(' ', '_') # if there is space in column names, change them to _

# %%
# only change specific columns
people_df.rename(columns={'first_name': 'First', 'last_name': 'Last'}, inplace=True)

people_df
# Out:
#                email  First     Last
# 0    corey@gmail.com  Corey  Schafer
# 1     jane@gmail.com   Jane      Doe
# 2  JohnDoe@gmail.com   John     Deer

# %%
people_df.loc[2] = ['JohnSmith@gmail.com', 'John', 'Smith']  # change/update a row
people_df
# Out:
#                  email  First     Last
# 0      corey@gmail.com  Corey  Schafer
# 1       jane@gmail.com   Jane      Doe
# 2  JohnSmith@gmail.com   John    Smith

# %%
people_df.loc[2, 'Last'] = 'Jones'  # update specific column at specific row
people_df

# people_df[filt]['Last'] = 'Jones'    *this will return an error
# Out:
#                  email  First     Last
# 0      corey@gmail.com  Corey  Schafer
# 1       jane@gmail.com   Jane      Doe
# 2  JohnSmith@gmail.com   John    Jones

# %%
people_df.at[2, 'Last'] = 'Doe' # update specific column at specific row
people_df
# Out:
#                  email  First     Last
# 0      corey@gmail.com  Corey  Schafer
# 1       jane@gmail.com   Jane      Doe
# 2  JohnSmith@gmail.com   John      Doe

# %%
filt = (people_df['email'] == 'JohnSmith@gmail.com')
people_df[filt]['Last']
# Out:
# 2    Doe
# Name: Last, dtype: object

# %%
people_df['email'] = people_df['email'].str.upper()  # how to make the upperCase change permanant on dataFrame

people_df
# Out:
#                  email  First     Last
# 0      COREY@GMAIL.COM  Corey  Schafer
# 1       JANE@GMAIL.COM   Jane      Doe
# 2  JOHNSMITH@GMAIL.COM   John      Doe

# %%
people_df['email'].apply(len)
# Out:
# 0    15
# 1    14
# 2    19
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.lower()

people_df['email'] = people_df['email'].apply(update_email)
people_df
# Out:
#                  email  First     Last
# 0      corey@gmail.com  Corey  Schafer
# 1       jane@gmail.com   Jane      Doe
# 2  johnsmith@gmail.com   John      Doe

# %%
people_df['First'] = people_df['First'].apply(lambda x: x.upper())
people_df
# Out:
#                  email  First     Last
# 0      corey@gmail.com  COREY  Schafer
# 1       jane@gmail.com   JANE      Doe
# 2  johnsmith@gmail.com   JOHN      Doe

# %%
people_df.apply(len)  # number of rows for each column
# Out:
# email    3
# First    3
# Last     3
# dtype: int64

# %%
len(people_df['email'])
# Out:
# 3

# %%
people_df.apply(len, axis='columns')  # number of columns for each row
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
people_df.apply(pd.Series.min)  # get smallest values for each column
# Out:
# email    corey@gmail.com
# First              COREY
# Last                 Doe
# dtype: object

# %%
people_df.applymap(len)   # applies len() function to each cell in the dataFrame
# Out:
#    email  First  Last
# 0     15      5     7
# 1     14      4     3
# 2     19      4     3

# %%
people_df.applymap(str.lower)  # this will return error if we had numerical values here
# Out:
#                  email  First     Last
# 0      corey@gmail.com  corey  schafer
# 1       jane@gmail.com   jane      doe
# 2  johnsmith@gmail.com   john      doe

# %%
people_df['First'] = people _df['First'].replace('corey', 'Bob')
people_df
# Out:
#   File "<ipython-input-55-945de171f21e>", line 1
#     people_df['First'] = people _df['First'].replace('corey', 'Bob')
#                                   ^
# SyntaxError: invalid syntax

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)  # rename column

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df['Hobbyist'].map({'Yes': True, 'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})  # anything outside Yes/No will be NaN

# %%
people_df['First'] + ' ' + people_df['Last']
# Out:
# 0    COREY Schafer
# 1         JANE Doe
# 2         JOHN Doe
# dtype: object

# %%
people_df['full_name'] = people_df['First'] + ' ' + people_df['Last']

# %%
people_df
# Out:
#                  email  First     Last      full_name
# 0      corey@gmail.com  COREY  Schafer  COREY Schafer
# 1       jane@gmail.com   JANE      Doe       JANE Doe
# 2  johnsmith@gmail.com   JOHN      Doe       JOHN Doe

# %%
people_df.drop(columns=['First', 'Last'], inplace=True) # will throw an error if the column names are spelled wrong

# %%
people_df
# Out:
#                  email      full_name
# 0      corey@gmail.com  COREY Schafer
# 1       jane@gmail.com       JANE Doe
# 2  johnsmith@gmail.com       JOHN Doe

# %%
people_df[['first', 'last']] = people_df['full_name'].str.split(' ', expand=True)
people_df.drop(columns=['full_name'], inplace=True)
people_df
# Out:
#                  email  first     last
# 0      corey@gmail.com  COREY  Schafer
# 1       jane@gmail.com   JANE      Doe
# 2  johnsmith@gmail.com   JOHN      Doe

# %%
people_df.append({'first': 'Tony'}, ignore_index=True)  # adding rows to dataframe
# Out:
#                  email  first     last
# 0      corey@gmail.com  COREY  Schafer
# 1       jane@gmail.com   JANE      Doe
# 2  johnsmith@gmail.com   JOHN      Doe
# 3                  NaN   Tony      NaN

# %%
people = {
    "first": ["dude", "duddete"],
    "last": ["one", "two"],
    "email": ["dude@gmail.com","duddete@gmail.com"]
}

people_df2 = pd.DataFrame(people)
people_df2
# Out:
#      first last              email
# 0     dude  one     dude@gmail.com
# 1  duddete  two  duddete@gmail.com

# %%
people_df = people_df.append(people_df2, ignore_index=True)  # append dataframes together
people_df
# Out:
#                  email    first     last
# 0      corey@gmail.com    COREY  Schafer
# 1       jane@gmail.com     JANE      Doe
# 2  johnsmith@gmail.com     JOHN      Doe
# 3       dude@gmail.com     dude      one
# 4    duddete@gmail.com  duddete      two

# %%
people_df.drop(index=4)   # drop rows
# Out:
#                  email  first     last
# 0      corey@gmail.com  COREY  Schafer
# 1       jane@gmail.com   JANE      Doe
# 2  johnsmith@gmail.com   JOHN      Doe
# 3       dude@gmail.com   dude      one

# %%
cond = (people_df['last'] == 'one')

people_df.drop(index=people_df[cond].index)
# Out:
#                  email    first     last
# 0      corey@gmail.com    COREY  Schafer
# 1       jane@gmail.com     JANE      Doe
# 2  johnsmith@gmail.com     JOHN      Doe
# 4    duddete@gmail.com  duddete      two

# %%
people_df.sort_values(by='last', ascending=False)  # sort by column
# Out:
#                  email    first     last
# 4    duddete@gmail.com  duddete      two
# 3       dude@gmail.com     dude      one
# 0      corey@gmail.com    COREY  Schafer
# 1       jane@gmail.com     JANE      Doe
# 2  johnsmith@gmail.com     JOHN      Doe

# %%
people_df.sort_values(by=['last', 'first'], ascending=False) # sort by several columns
# Out:
#                  email    first     last
# 4    duddete@gmail.com  duddete      two
# 3       dude@gmail.com     dude      one
# 0      corey@gmail.com    COREY  Schafer
# 2  johnsmith@gmail.com     JOHN      Doe
# 1       jane@gmail.com     JANE      Doe

# %%
 people_df.sort_index() # sort by index
# Out:
#                  email    first     last
# 0      corey@gmail.com    COREY  Schafer
# 1       jane@gmail.com     JANE      Doe
# 2  johnsmith@gmail.com     JOHN      Doe
# 3       dude@gmail.com     dude      one
# 4    duddete@gmail.com  duddete      two

# %%
df.sort_values(by=['Country', 'SalaryUSD'], ascending=[True, False], inplace=True)
df[['Country', 'SalaryUSD']].head(10)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0
# 22450       Afghanistan     7980.0
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 8149        Afghanistan     1596.0
# 29736       Afghanistan     1116.0

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(3, 'SalaryUSD')
# Out:
#                                 MainBranch  Hobbyist              OpenSourcer  \
# Respondent
# 25983       I am a developer by profession      True  Less than once per year
# 87896       I am a developer by profession      True  Less than once per year
# 22013       I am a developer by profession      True                    Never
#
#                                                    OpenSource  \
# Respondent
# 25983       OSS is, on average, of HIGHER quality than pro...
# 87896       The quality of OSS and closed source software ...
# 22013       The quality of OSS and closed source software ...
#
#                     Employment  Country Student  \
# Respondent
# 25983       Employed full-time   Canada      No
# 87896       Employed full-time  Germany      No
# 22013       Employed full-time    India      No
#
#                                              EdLevel  \
# Respondent
# 25983       Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...

# %%
# aggregation: mean | median | mode
df['SalaryUSD'].median()
# Out:
# 57287.0

# %%
df.median()  # only shows numerical values
# Out:
# Hobbyist           1.0
# CompTotal      62000.0
# SalaryUSD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df[df['Country'] == 'United States']['SalaryUSD'].median()
# Out:
# 110000.0

# %%
df[df['Country'] == 'India']['SalaryUSD'].mean()
# Out:
# 28057.664916229056

# %%
df[df['Country'] == 'South Africa']['SalaryUSD'].median()
# Out:
# 38354.0

# %%
df.describe()
# Out:
#           CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['Hobbyist'].value_counts()
# Out:
# True     71257
# False    17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Timor-Leste                             1
# Chad                                    1
# Saint Vincent and the Grenadines        1
# Saint Kitts and Nevis                   1
# Name: Country, Length: 179, dtype: int64

# %%
country_group = df.groupby(['Country'])  # group dataframe based on country

# %%
country_group.get_group('United States')
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 58          I am a developer by profession      True
# 102         I am a developer by profession     False
# 166         I am a developer by profession      True
# 436         I am a developer by profession      True
# 452         I am a developer by profession      True
# ...                                    ...       ...
# 78292                                  NaN     False
# 82717                                  NaN     False
# 83397                                  NaN      True
# 85642                                  NaN     False
# 88282                                  NaN      True
#
#                            OpenSourcer  \
# Respondent
# 58          Once a month or more often
# 102                              Never
# 166            Less than once per year
# 436            Less than once per year
# 452                              Never
# ...                                ...
# ...

# %%
filt = df['Country'] == 'United States'
custom_df = df.loc[filt]

# difference between code above and groupby is that

# %%
df.loc[filt]['SocialMedia'].value_counts()  # value count for social media users in the united states
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
country_group['SocialMedia'].value_counts().head(10)  # social media count by the country
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#              LinkedIn                     1
#              Twitter                      1
# Albania      WhatsApp                    18
#              Facebook                    16
#              Instagram                   13
# Name: SocialMedia, dtype: int64

# %%
country_group['SocialMedia'].value_counts().loc['Sweden']
# Out:
# SocialMedia
# Reddit                      289
# YouTube                     233
# Facebook                    214
# Twitter                     143
# Instagram                   116
# I don't use social media     89
# WhatsApp                     72
# LinkedIn                     53
# Snapchat                     21
# WeChat 微信                     2
# VK ВКонта́кте                 1
# Name: SocialMedia, dtype: int64

# %%
country_group['SalaryUSD'].median().loc['Sweden']  # since name of country becomes index, we can use .loc here
# Out:
# 56004.0

# %%
country_group['SalaryUSD'].agg(['median', 'mean']).loc['United States']
# Out:
# median    110000.000000
# mean      249546.254589
# Name: United States, dtype: float64

# %%
filt = (df['Country'] == 'India')  # how many indian programmers know python
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()

# .sum() counts True as 1 and False as 0
# Out:
# 3105

# %%
# here we check how many devs in each country know python
# for groupedby series you can't use aggregation directly, use .apply()
country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
# total number of devs in each ccountry
country_respondants = df['Country'].value_counts()
# how many devs in each country know python
country_python = country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

python_df = pd.concat([country_respondants, country_python], axis='columns', sort=False) # add dataframes side by side
python_df.rename(columns={'Country': 'NumRespondants', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)
python_df['pctPython'] = (python_df['NumKnowsPython'] / python_df['NumRespondants']) * 100

# %%
python_df[python_df['NumRespondants'] > 100].sort_values(by='pctPython', ascending=False)
# Out:
#                                   NumRespondants  NumKnowsPython  pctPython
# South Korea                                  160              80  50.000000
# Chile                                        206             102  49.514563
# Finland                                      546             266  48.717949
# Kenya                                        249             120  48.192771
# United States                              20949           10083  48.131176
# Israel                                       952             457  48.004202
# Taiwan                                       187              88  47.058824
# Switzerland                                  978             460  47.034765
# Hong Kong (S.A.R.)                           188              88  46.808511
# Japan                                        391             182  46.547315
# Canada                                      3395            1558  45.891016
# ...

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

df_1 = pd.DataFrame(people)

df_1.replace('NA', np.nan, inplace=True)
df_1.replace('Missing', np.nan, inplace=True)

# %%
df_1.dropna() # dropna() deletes any line that includes a NaN value
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
df_1.dropna(axis='index', how='any') 
# if axis is name of any other column, if we had NaN there, it would drop the whole column
# if "how" is set to all, we would only drop columns that have all values missing
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
df_1.dropna(axis='index', how='all', subset=['email', 'last']) # only drop rows if email AND last name are missing
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 5   None      NaN      Anonymous@email.com  None

# %%
df_1.isna()  # returns True if value is considered na
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df_1.fillna("MISSING")
# Out:
#      first     last                    email      age
# 0    Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1     Jane      Doe        JaneDoe@email.com       55
# 2     John      Doe        JohnDoe@email.com       63
# 3    Chris  Schafer                  MISSING       36
# 4  MISSING  MISSING                  MISSING  MISSING
# 5  MISSING  MISSING      Anonymous@email.com  MISSING
# 6  MISSING  MISSING                  MISSING  MISSING

# %%
type(np.nan)
# Out:
# float

# %%
df_1['age'] = df_1['age'].astype(float)  # if we have missing values, then we can't cast to integer
type(df_1['age'].loc[3])
# Out:
# numpy.float64

# %%
df_1['age'].mean()
# Out:
# 46.75

# %%
df['YearsCode'].unique()
# Out:
# array(['Less than 1 year', '7', '2', '6', '3', '4', '10', '36', '1', nan,
#        'More than 50 years', '20', '9', '5', '8', '31', '28', '15', '13',
#        '12', '17', '18', '21', '35', '14', '25', '11', '19', '22', '23',
#        '40', '39', '30', '43', '27', '33', '29', '24', '34', '16', '32',
#        '26', '38', '44', '41', '45', '37', '47', '42', '46', '48', '50',
#        '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
# READING AND WRITING FILES WITH PANDAS

# %%
filt = (df['Country'] == 'United States')
us_df = df.loc[filt]
us_df.head(1)
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 58          I am a developer by profession      True
#
#                            OpenSourcer  \
# Respondent
# 58          Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 58          OSS is, on average, of LOWER quality than prop...
#
#                     Employment        Country Student  \
# Respondent
# 58          Employed full-time  United States      No
#
#                                              EdLevel  \
# Respondent
# 58          Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 58          Computer science, computer engineering, or sof...
#
#                                                      EduOther OrgSize  \
# Respondent
# 58          Received on-the-job training in software devel...     NaN
#
# ...

# %%
# export dataframe to a csv file:
us_df.to_csv('data/modified.csv')

# %%
us_df.to_csv('data/modified.tsv', sep='\t')

# %%
# libraries needed when working with excel : "xlwt"  "xlrd"  "openpyxl"

# %%
# export dataframe to excel
us_df.to_excel('data/modified.xlsx')

# %%
test = pd.read_excel('data/modified.xlsx', index_col='Respondent')

# %%
test.head(2)
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 58          I am a developer by profession      True
# 102         I am a developer by profession     False
#
#                            OpenSourcer  \
# Respondent
# 58          Once a month or more often
# 102                              Never
#
#                                                    OpenSource  \
# Respondent
# 58          OSS is, on average, of LOWER quality than prop...
# 102         The quality of OSS and closed source software ...
#
#                     Employment        Country Student  \
# Respondent
# 58          Employed full-time  United States      No
# 102         Employed full-time  United States      No
#
#                                              EdLevel  \
# Respondent
# 58          Bachelor’s degree (BA, BS, B.Eng., etc.)
# 102         Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# ...

# %%
# writing to a json file
us_df.to_json('data/modified.json', orient='records', lines=True) # orient=records makes it look more readable

# %%
test = pd.read_json('data/modified.json', orient='records', lines=True)
test.head(2)
# Out:
#                        MainBranch  Hobbyist                 OpenSourcer  \
# 0  I am a developer by profession      True  Once a month or more often
# 1  I am a developer by profession     False                       Never
#
#                                           OpenSource          Employment  \
# 0  OSS is, on average, of LOWER quality than prop...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
#
#          Country Student                                   EdLevel  \
# 0  United States      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  United States      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 0  Computer science, computer engineering, or sof...
# 1  Computer science, computer engineering, or sof...
#
#                                             EduOther  \
# 0  Received on-the-job training in software devel...
# ...

# %%
# writing and reading with Postgres
# libraries needed: "SQLAlchemy"  "psycopg2-binary"

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://dummyUser:dummyPass@localhost:5432/dummyDB')

# %%
engine
# Out:
# Engine(postgresql://dummyUser:***@localhost:5432/dummyDB)

# %%
us_df.to_sql('dummy_table', engine)  # export dataframe to sql table

# %%
us_df.to_sql('dummy_table', engine, if_exists='replace')  # rewrite table with new data

# %%
sql_df = pd.read_sql('dummy_table', engine) # load sql table to dataframe

# %%
sql_df_query = pd.read_sql_query("select * from dummy_table where Country='United States'", engine)
# reading from sql query
